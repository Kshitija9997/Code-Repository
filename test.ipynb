# %% [markdown]
# #  Test Code - 50 startups

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd

# %% [markdown]
# ### read the Dataset

# %%
df= pd.read_csv('50_Startups.csv')

# %%
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'STATE', 'PROFIT'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isna().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %% [markdown]
# ### Sepererate Categorical and Contineous features

# %%
cat= list(df.columns[df.dtypes=='object'])
con= list(df.columns[df.dtypes!='object'])

# %%
cat
# Out:
# ['STATE']

# %%
con
# Out:
# ['RND', 'ADMIN', 'MKT', 'PROFIT']

# %% [markdown]
# ### Descriptive analysis

# %%
df[cat].describe().T
# Out:
#       count unique       top freq
# STATE    50      3  New York   17

# %%
df['STATE'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
df[con].describe().T
# Out:
#         count         mean            std       min          25%         50%  \
# RND      50.0   73721.6156   45902.256482      0.00   39936.3700   73051.080
# ADMIN    50.0  121344.6396   28017.802755  51283.14  103730.8750  122699.795
# MKT      50.0  211025.0978  122290.310726      0.00  129300.1325  212716.240
# PROFIT   50.0  112012.6392   40306.180338  14681.40   90138.9025  107978.190
#
#                 75%        max
# RND     101602.8000  165349.20
# ADMIN   144842.1800  182645.56
# MKT     299469.0850  471784.10
# PROFIT  139765.9775  192261.83

# %% [markdown]
# ### Univariate Analysis

# %%
df['STATE'].value_counts().plot(kind='bar',
                                xlabel='STATE',
                                ylabel='COUNT',
                                title='Countplot for State')
# Out:
# <Axes: title={'center': 'Countplot for State'}, xlabel='STATE', ylabel='COUNT'>

# %% [markdown]
# ### For Contineous features

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for i in con:
    sns.histplot(data=df, x=i, kde=True)
    plt.title(f'Histplotfor {i}')
    plt.show()

# %% [markdown]
# ### Histogram based on state

# %%
for i in con:
    sns.histplot(data=df, x=i, kde=True, hue='STATE')
    plt.title(f'Histplot for {i} with respect to STATE')
    plt.show()
